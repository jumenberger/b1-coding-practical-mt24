# %%
# Add relevant Jupyter notebook extensions

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\python311.zip', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\DLLs', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\Lib', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0', 'c:\\Users\\navik\\Documents\\Year_3\\B1\\.venvs\\mission_venv', '', 'c:\\Users\\navik\\Documents\\Year_3\\B1\\.venvs\\mission_venv\\Lib\\site-packages', 'c:\\Users\\navik\\Documents\\Year_3\\B1\\.venvs\\mission_venv\\Lib\\site-packages\\win32', 'c:\\Users\\navik\\Documents\\Year_3\\B1\\.venvs\\mission_venv\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\navik\\Documents\\Year_3\\B1\\.venvs\\mission_venv\\Lib\\site-packages\\Pythonwin']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from control import controller
from dynamic import ClosedLoop
from dynamic import Mission
from dynamic import Submarine
sub = Submarine()
controller=controller(Kp=1,Kd=1.5)
# Instantiate your controller (depending on your implementation)
closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv(r'c:\Users\navik\Documents\Year_3\B1\b1-coding-practical-mt24\data\mission.csv') # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
